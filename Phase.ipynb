# %% [markdown]
# <a href="https://colab.research.google.com/github/Susmitapaul45/VoiceRecognition/blob/main/Phase.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install librosa pandas
# Out:
# Requirement already satisfied: librosa in /usr/local/lib/python3.11/dist-packages (0.10.2.post1)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (2.2.2)
# Requirement already satisfied: audioread>=2.1.9 in /usr/local/lib/python3.11/dist-packages (from librosa) (3.0.1)
# Requirement already satisfied: numpy!=1.22.0,!=1.22.1,!=1.22.2,>=1.20.3 in /usr/local/lib/python3.11/dist-packages (from librosa) (1.26.4)
# Requirement already satisfied: scipy>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from librosa) (1.13.1)
# Requirement already satisfied: scikit-learn>=0.20.0 in /usr/local/lib/python3.11/dist-packages (from librosa) (1.6.0)
# Requirement already satisfied: joblib>=0.14 in /usr/local/lib/python3.11/dist-packages (from librosa) (1.4.2)
# Requirement already satisfied: decorator>=4.3.0 in /usr/local/lib/python3.11/dist-packages (from librosa) (4.4.2)
# Requirement already satisfied: numba>=0.51.0 in /usr/local/lib/python3.11/dist-packages (from librosa) (0.60.0)
# Requirement already satisfied: soundfile>=0.12.1 in /usr/local/lib/python3.11/dist-packages (from librosa) (0.13.0)
# Requirement already satisfied: pooch>=1.1 in /usr/local/lib/python3.11/dist-packages (from librosa) (1.8.2)
# Requirement already satisfied: soxr>=0.3.2 in /usr/local/lib/python3.11/dist-packages (from librosa) (0.5.0.post1)
# Requirement already satisfied: typing-extensions>=4.1.1 in /usr/local/lib/python3.11/dist-packages (from librosa) (4.12.2)
# Requirement already satisfied: lazy-loader>=0.1 in /usr/local/lib/python3.11/dist-packages (from librosa) (0.4)
# Requirement already satisfied: msgpack>=1.0 in /usr/local/lib/python3.11/dist-packages (from librosa) (1.1.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas) (2024.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from lazy-loader>=0.1->librosa) (24.2)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.11/dist-packages (from numba>=0.51.0->librosa) (0.43.0)
# Requirement already satisfied: platformdirs>=2.5.0 in /usr/local/lib/python3.11/dist-packages (from pooch>=1.1->librosa) (4.3.6)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.11/dist-packages (from pooch>=1.1->librosa) (2.32.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=0.20.0->librosa) (3.5.0)
# Requirement already satisfied: cffi>=1.0 in /usr/local/lib/python3.11/dist-packages (from soundfile>=0.12.1->librosa) (1.17.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.0->soundfile>=0.12.1->librosa) (2.22)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->pooch>=1.1->librosa) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->pooch>=1.1->librosa) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->pooch>=1.1->librosa) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.19.0->pooch>=1.1->librosa) (2024.12.14)

# %%
import os
from pydub import AudioSegment
import librosa
import pandas as pd

# Define input and output directories
input_folder = '/content/sample_data/Different_phase'  # Replace with the directory containing FLAC files
mp3_folder = '/content/sample_data/mp3folder_different'   # Directory to store converted MP3 files
output_csv = 'different.csv'               # Path to save the CSV file

# Ensure the MP3 output folder exists
os.makedirs(mp3_folder, exist_ok=True)

# Step 1: Convert FLAC files to MP3
print("Converting FLAC files to MP3...")
for filename in os.listdir(input_folder):
    if filename.endswith('.flac'):
        flac_path = os.path.join(input_folder, filename)
        mp3_path = os.path.join(mp3_folder, os.path.splitext(filename)[0] + '.mp3')

        try:
            # Load the FLAC file
            audio = AudioSegment.from_file(flac_path, format="flac")

            # Export as MP3
            audio.export(mp3_path, format="mp3", bitrate="192k")
            print(f"Converted {filename} to {mp3_path}")
        except Exception as e:
            print(f"Error converting {filename}: {e}")

# Step 2: Extract audio features from MP3 files
print("Extracting audio features from MP3 files...")
data = []

for filename in os.listdir(mp3_folder):
    if filename.endswith('.mp3'):  # Process .mp3 files
        file_path = os.path.join(mp3_folder, filename)

        try:
            # Load audio file using librosa
            y, sr = librosa.load(file_path, sr=None)  # y: audio time series, sr: sample rate

            # Extract features
            zero_crossing_rate = librosa.feature.zero_crossing_rate(y).mean()
            spectral_centroid = librosa.feature.spectral_centroid(y=y, sr=sr).mean()
            spectral_bandwidth = librosa.feature.spectral_bandwidth(y=y, sr=sr).mean()
            roll_off = librosa.feature.spectral_rolloff(y=y, sr=sr).mean()
            rms = librosa.feature.rms(y=y).mean()
            tempo, _ = librosa.beat.beat_track(y=y, sr=sr)

            # Append the extracted features to the data list
            data.append({
                'Filename': filename,
                'ZeroCrossingRate': zero_crossing_rate,
                'SpectralCentroid': spectral_centroid,
                'SpectralBandwidth': spectral_bandwidth,
                'RollOff': roll_off,
                'RMS': rms,
                'Tempo': tempo
            })
        except Exception as e:
            print(f"Error processing {file_path}: {e}")

# Step 3: Save features to CSV
if data:
    df = pd.DataFrame(data)
    df.to_csv(output_csv, index=False)
    print(f"CSV file saved as {output_csv}")
else:
    print("No audio features were extracted. Check the input files.")
# Out:
# Converting FLAC files to MP3...
# Converted 99-19.flac to /content/sample_data/mp3folder_different/99-19.mp3
# Converted 78-14.flac to /content/sample_data/mp3folder_different/78-14.mp3
# Converted 31-20.flac to /content/sample_data/mp3folder_different/31-20.mp3
# Converted 109-20.flac to /content/sample_data/mp3folder_different/109-20.mp3
# Converted 74-13.flac to /content/sample_data/mp3folder_different/74-13.mp3
# Converted 118-16.flac to /content/sample_data/mp3folder_different/118-16.mp3
# Converted 125-13.flac to /content/sample_data/mp3folder_different/125-13.mp3
# Converted 55-15.flac to /content/sample_data/mp3folder_different/55-15.mp3
# Converted 75-13.flac to /content/sample_data/mp3folder_different/75-13.mp3
# Converted 8-19.flac to /content/sample_data/mp3folder_different/8-19.mp3
# Converted 78-18.flac to /content/sample_data/mp3folder_different/78-18.mp3
# Converted 114-18.flac to /content/sample_data/mp3folder_different/114-18.mp3
# Converted 124-13.flac to /content/sample_data/mp3folder_different/124-13.mp3
# Converted 25-13.flac to /content/sample_data/mp3folder_different/25-13.mp3
# Converted 12-11.flac to /content/sample_data/mp3folder_different/12-11.mp3
# Converted 87-14.flac to /content/sample_data/mp3folder_different/87-14.mp3
# Converted 15-19.flac to /content/sample_data/mp3folder_different/15-19.mp3
# Converted 40-16.flac to /content/sample_data/mp3folder_different/40-16.mp3
# Converted 97-19.flac to /content/sample_data/mp3folder_different/97-19.mp3
# Converted 57-19.flac to /content/sample_data/mp3folder_different/57-19.mp3
# Converted 8-20.flac to /content/sample_data/mp3folder_different/8-20.mp3
# Converted 43-16.flac to /content/sample_data/mp3folder_different/43-16.mp3
# Converted 141-12.flac to /content/sample_data/mp3folder_different/141-12.mp3
# Converted 5-15.flac to /content/sample_data/mp3folder_different/5-15.mp3
# Converted 50-15.flac to /content/sample_data/mp3folder_different/50-15.mp3
# Converted 31-14.flac to /content/sample_data/mp3folder_different/31-14.mp3
# Converted 101-11.flac to /content/sample_data/mp3folder_different/101-11.mp3
# Converted 82-20.flac to /content/sample_data/mp3folder_different/82-20.mp3
# Converted 57-15.flac to /content/sample_data/mp3folder_different/57-15.mp3
# Converted 143-14.flac to /content/sample_data/mp3folder_different/143-14.mp3
# Converted 41-19.flac to /content/sample_data/mp3folder_different/41-19.mp3
# Converted 34-11.flac to /content/sample_data/mp3folder_different/34-11.mp3
# Converted 141-20.flac to /content/sample_data/mp3folder_different/141-20.mp3
# Converted 34-15.flac to /content/sample_data/mp3folder_different/34-15.mp3
# Converted 1-17.flac to /content/sample_data/mp3folder_different/1-17.mp3
# Converted 16-20.flac to /content/sample_data/mp3folder_different/16-20.mp3
# Converted 50-19.flac to /content/sample_data/mp3folder_different/50-19.mp3
# Converted 109-16.flac to /content/sample_data/mp3folder_different/109-16.mp3
# Converted 144-15.flac to /content/sample_data/mp3folder_different/144-15.mp3
# Converted 60-18.flac to /content/sample_data/mp3folder_different/60-18.mp3
# Converted 129-15.flac to /content/sample_data/mp3folder_different/129-15.mp3
# Converted 122-18.flac to /content/sample_data/mp3folder_different/122-18.mp3
# Converted 4-14.flac to /content/sample_data/mp3folder_different/4-14.mp3
# Converted 127-13.flac to /content/sample_data/mp3folder_different/127-13.mp3
# Converted 69-17.flac to /content/sample_data/mp3folder_different/69-17.mp3
# Converted 57-18.flac to /content/sample_data/mp3folder_different/57-18.mp3
# Converted 1-14.flac to /content/sample_data/mp3folder_different/1-14.mp3
# Converted 103-12.flac to /content/sample_data/mp3folder_different/103-12.mp3
# Converted 145-12.flac to /content/sample_data/mp3folder_different/145-12.mp3
# Converted 111-13.flac to /content/sample_data/mp3folder_different/111-13.mp3
# Converted 59-15.flac to /content/sample_data/mp3folder_different/59-15.mp3
# Converted 90-18.flac to /content/sample_data/mp3folder_different/90-18.mp3
# Converted 92-17.flac to /content/sample_data/mp3folder_different/92-17.mp3
# Converted 129-20.flac to /content/sample_data/mp3folder_different/129-20.mp3
# Converted 70-19.flac to /content/sample_data/mp3folder_different/70-19.mp3
# Converted 26-16.flac to /content/sample_data/mp3folder_different/26-16.mp3
# Converted 97-11.flac to /content/sample_data/mp3folder_different/97-11.mp3
# Converted 14-17.flac to /content/sample_data/mp3folder_different/14-17.mp3
# Converted 95-16.flac to /content/sample_data/mp3folder_different/95-16.mp3
# Converted 58-19.flac to /content/sample_data/mp3folder_different/58-19.mp3
# Converted 51-20.flac to /content/sample_data/mp3folder_different/51-20.mp3
# Converted 32-14.flac to /content/sample_data/mp3folder_different/32-14.mp3
# Converted 97-13.flac to /content/sample_data/mp3folder_different/97-13.mp3
# Converted 111-11.flac to /content/sample_data/mp3folder_different/111-11.mp3
# Converted 67-11.flac to /content/sample_data/mp3folder_different/67-11.mp3
# Converted 65-18.flac to /content/sample_data/mp3folder_different/65-18.mp3
# Converted 133-14.flac to /content/sample_data/mp3folder_different/133-14.mp3
# Converted 148-18.flac to /content/sample_data/mp3folder_different/148-18.mp3
# Converted 71-12.flac to /content/sample_data/mp3folder_different/71-12.mp3
# Converted 40-13.flac to /content/sample_data/mp3folder_different/40-13.mp3
# Converted 48-19.flac to /content/sample_data/mp3folder_different/48-19.mp3
# Converted 57-13.flac to /content/sample_data/mp3folder_different/57-13.mp3
# Converted 48-14.flac to /content/sample_data/mp3folder_different/48-14.mp3
# Converted 29-17.flac to /content/sample_data/mp3folder_different/29-17.mp3
# Converted 17-16.flac to /content/sample_data/mp3folder_different/17-16.mp3
# Converted 104-13.flac to /content/sample_data/mp3folder_different/104-13.mp3
# Converted 141-15.flac to /content/sample_data/mp3folder_different/141-15.mp3
# Converted 113-12.flac to /content/sample_data/mp3folder_different/113-12.mp3
# Converted 125-15.flac to /content/sample_data/mp3folder_different/125-15.mp3
# Converted 39-11.flac to /content/sample_data/mp3folder_different/39-11.mp3
# Converted 82-18.flac to /content/sample_data/mp3folder_different/82-18.mp3
# Converted 37-19.flac to /content/sample_data/mp3folder_different/37-19.mp3
# Converted 31-18.flac to /content/sample_data/mp3folder_different/31-18.mp3
# Converted 37-14.flac to /content/sample_data/mp3folder_different/37-14.mp3
# Converted 11-17.flac to /content/sample_data/mp3folder_different/11-17.mp3
# Converted 59-11.flac to /content/sample_data/mp3folder_different/59-11.mp3
# Converted 140-14.flac to /content/sample_data/mp3folder_different/140-14.mp3
# Converted 68-14.flac to /content/sample_data/mp3folder_different/68-14.mp3
# Converted 28-18.flac to /content/sample_data/mp3folder_different/28-18.mp3
# Converted 111-18.flac to /content/sample_data/mp3folder_different/111-18.mp3
# Converted 121-19.flac to /content/sample_data/mp3folder_different/121-19.mp3
# Converted 19-16.flac to /content/sample_data/mp3folder_different/19-16.mp3
# Converted 13-16.flac to /content/sample_data/mp3folder_different/13-16.mp3
# Converted 9-19.flac to /content/sample_data/mp3folder_different/9-19.mp3
# Converted 17-12.flac to /content/sample_data/mp3folder_different/17-12.mp3
# Converted 19-11.flac to /content/sample_data/mp3folder_different/19-11.mp3
# Converted 102-15.flac to /content/sample_data/mp3folder_different/102-15.mp3
# Converted 43-17.flac to /content/sample_data/mp3folder_different/43-17.mp3
# Converted 31-13.flac to /content/sample_data/mp3folder_different/31-13.mp3
# Converted 145-20.flac to /content/sample_data/mp3folder_different/145-20.mp3
# Converted 15-15.flac to /content/sample_data/mp3folder_different/15-15.mp3
# Converted 129-19.flac to /content/sample_data/mp3folder_different/129-19.mp3
# Converted 35-16.flac to /content/sample_data/mp3folder_different/35-16.mp3
# Converted 104-14.flac to /content/sample_data/mp3folder_different/104-14.mp3
# Converted 35-20.flac to /content/sample_data/mp3folder_different/35-20.mp3
# Converted 56-19.flac to /content/sample_data/mp3folder_different/56-19.mp3
# Converted 137-14.flac to /content/sample_data/mp3folder_different/137-14.mp3
# Converted 74-17.flac to /content/sample_data/mp3folder_different/74-17.mp3
# Converted 128-14.flac to /content/sample_data/mp3folder_different/128-14.mp3
# Converted 141-13.flac to /content/sample_data/mp3folder_different/141-13.mp3
# Converted 14-12.flac to /content/sample_data/mp3folder_different/14-12.mp3
# Converted 149-15.flac to /content/sample_data/mp3folder_different/149-15.mp3
# Converted 131-20.flac to /content/sample_data/mp3folder_different/131-20.mp3
# Converted 140-20.flac to /content/sample_data/mp3folder_different/140-20.mp3
# Converted 19-19.flac to /content/sample_data/mp3folder_different/19-19.mp3
# Converted 15-13.flac to /content/sample_data/mp3folder_different/15-13.mp3
# Converted 11-20.flac to /content/sample_data/mp3folder_different/11-20.mp3
# Converted 138-14.flac to /content/sample_data/mp3folder_different/138-14.mp3
# Converted 117-14.flac to /content/sample_data/mp3folder_different/117-14.mp3
# Converted 60-17.flac to /content/sample_data/mp3folder_different/60-17.mp3
# Converted 10-18.flac to /content/sample_data/mp3folder_different/10-18.mp3
# Converted 144-16.flac to /content/sample_data/mp3folder_different/144-16.mp3
# Converted 81-12.flac to /content/sample_data/mp3folder_different/81-12.mp3
# Converted 119-11.flac to /content/sample_data/mp3folder_different/119-11.mp3
# Converted 98-20.flac to /content/sample_data/mp3folder_different/98-20.mp3
# Converted 93-13.flac to /content/sample_data/mp3folder_different/93-13.mp3
# Converted 42-15.flac to /content/sample_data/mp3folder_different/42-15.mp3
# Converted 23-13.flac to /content/sample_data/mp3folder_different/23-13.mp3
# Converted 148-13.flac to /content/sample_data/mp3folder_different/148-13.mp3
# Converted 4-15.flac to /content/sample_data/mp3folder_different/4-15.mp3
# Converted 98-19.flac to /content/sample_data/mp3folder_different/98-19.mp3
# Converted 54-20.flac to /content/sample_data/mp3folder_different/54-20.mp3
# Converted 49-18.flac to /content/sample_data/mp3folder_different/49-18.mp3
# Converted 3-12.flac to /content/sample_data/mp3folder_different/3-12.mp3
# Converted 135-19.flac to /content/sample_data/mp3folder_different/135-19.mp3
# Converted 32-20.flac to /content/sample_data/mp3folder_different/32-20.mp3
# Converted 59-16.flac to /content/sample_data/mp3folder_different/59-16.mp3
# Converted 72-13.flac to /content/sample_data/mp3folder_different/72-13.mp3
# Converted 20-17.flac to /content/sample_data/mp3folder_different/20-17.mp3
# Converted 39-12.flac to /content/sample_data/mp3folder_different/39-12.mp3
# Converted 118-15.flac to /content/sample_data/mp3folder_different/118-15.mp3
# Converted 49-17.flac to /content/sample_data/mp3folder_different/49-17.mp3
# Converted 70-13.flac to /content/sample_data/mp3folder_different/70-13.mp3
# Converted 92-16.flac to /content/sample_data/mp3folder_different/92-16.mp3
# Converted 27-15.flac to /content/sample_data/mp3folder_different/27-15.mp3
# Converted 29-20.flac to /content/sample_data/mp3folder_different/29-20.mp3
# Converted 149-20.flac to /content/sample_data/mp3folder_different/149-20.mp3
# Converted 88-15.flac to /content/sample_data/mp3folder_different/88-15.mp3
# Converted 46-18.flac to /content/sample_data/mp3folder_different/46-18.mp3
# Converted 131-18.flac to /content/sample_data/mp3folder_different/131-18.mp3
# Converted 13-19.flac to /content/sample_data/mp3folder_different/13-19.mp3
# Converted 96-17.flac to /content/sample_data/mp3folder_different/96-17.mp3
# Converted 124-11.flac to /content/sample_data/mp3folder_different/124-11.mp3
# Converted 12-19.flac to /content/sample_data/mp3folder_different/12-19.mp3
# Converted 126-18.flac to /content/sample_data/mp3folder_different/126-18.mp3
# Converted 125-12.flac to /content/sample_data/mp3folder_different/125-12.mp3
# Converted 17-13.flac to /content/sample_data/mp3folder_different/17-13.mp3
# Converted 83-15.flac to /content/sample_data/mp3folder_different/83-15.mp3
# Converted 116-13.flac to /content/sample_data/mp3folder_different/116-13.mp3
# Converted 137-17.flac to /content/sample_data/mp3folder_different/137-17.mp3
# Converted 60-20.flac to /content/sample_data/mp3folder_different/60-20.mp3
# Converted 134-20.flac to /content/sample_data/mp3folder_different/134-20.mp3
# Converted 118-18.flac to /content/sample_data/mp3folder_different/118-18.mp3
# Converted 120-15.flac to /content/sample_data/mp3folder_different/120-15.mp3
# Converted 86-16.flac to /content/sample_data/mp3folder_different/86-16.mp3
# Converted 78-15.flac to /content/sample_data/mp3folder_different/78-15.mp3
# Converted 130-15.flac to /content/sample_data/mp3folder_different/130-15.mp3
# Converted 123-15.flac to /content/sample_data/mp3folder_different/123-15.mp3
# Converted 22-13.flac to /content/sample_data/mp3folder_different/22-13.mp3
# Converted 21-13.flac to /content/sample_data/mp3folder_different/21-13.mp3
# Converted 5-16.flac to /content/sample_data/mp3folder_different/5-16.mp3
# Converted 93-15.flac to /content/sample_data/mp3folder_different/93-15.mp3
# Converted 32-15.flac to /content/sample_data/mp3folder_different/32-15.mp3
# Converted 86-14.flac to /content/sample_data/mp3folder_different/86-14.mp3
# Converted 26-15.flac to /content/sample_data/mp3folder_different/26-15.mp3
# Converted 130-12.flac to /content/sample_data/mp3folder_different/130-12.mp3
# Converted 111-14.flac to /content/sample_data/mp3folder_different/111-14.mp3
# Converted 111-19.flac to /content/sample_data/mp3folder_different/111-19.mp3
# Converted 25-19.flac to /content/sample_data/mp3folder_different/25-19.mp3
# Converted 129-13.flac to /content/sample_data/mp3folder_different/129-13.mp3
# Converted 30-14.flac to /content/sample_data/mp3folder_different/30-14.mp3
# Converted 101-14.flac to /content/sample_data/mp3folder_different/101-14.mp3
# Converted 91-16.flac to /content/sample_data/mp3folder_different/91-16.mp3
# Converted 12-13.flac to /content/sample_data/mp3folder_different/12-13.mp3
# Converted 56-14.flac to /content/sample_data/mp3folder_different/56-14.mp3
# Converted 30-12.flac to /content/sample_data/mp3folder_different/30-12.mp3
# Converted 110-13.flac to /content/sample_data/mp3folder_different/110-13.mp3
# Converted 55-17.flac to /content/sample_data/mp3folder_different/55-17.mp3
# Converted 142-15.flac to /content/sample_data/mp3folder_different/142-15.mp3
# Converted 100-15.flac to /content/sample_data/mp3folder_different/100-15.mp3
# Converted 96-16.flac to /content/sample_data/mp3folder_different/96-16.mp3
# Converted 118-11.flac to /content/sample_data/mp3folder_different/118-11.mp3
# Converted 53-17.flac to /content/sample_data/mp3folder_different/53-17.mp3
# Converted 139-12.flac to /content/sample_data/mp3folder_different/139-12.mp3
# Converted 55-19.flac to /content/sample_data/mp3folder_different/55-19.mp3
# Converted 103-17.flac to /content/sample_data/mp3folder_different/103-17.mp3
# Converted 145-18.flac to /content/sample_data/mp3folder_different/145-18.mp3
# Converted 54-16.flac to /content/sample_data/mp3folder_different/54-16.mp3
# Converted 114-17.flac to /content/sample_data/mp3folder_different/114-17.mp3
# Converted 137-16.flac to /content/sample_data/mp3folder_different/137-16.mp3
# Converted 103-18.flac to /content/sample_data/mp3folder_different/103-18.mp3
# Converted 89-11.flac to /content/sample_data/mp3folder_different/89-11.mp3
# Converted 138-12.flac to /content/sample_data/mp3folder_different/138-12.mp3
# Converted 34-16.flac to /content/sample_data/mp3folder_different/34-16.mp3
# Converted 129-17.flac to /content/sample_data/mp3folder_different/129-17.mp3
# Converted 18-18.flac to /content/sample_data/mp3folder_different/18-18.mp3
# Converted 48-18.flac to /content/sample_data/mp3folder_different/48-18.mp3
# Converted 144-13.flac to /content/sample_data/mp3folder_different/144-13.mp3
# Converted 28-16.flac to /content/sample_data/mp3folder_different/28-16.mp3
# Converted 54-17.flac to /content/sample_data/mp3folder_different/54-17.mp3
# Converted 81-14.flac to /content/sample_data/mp3folder_different/81-14.mp3
# Converted 71-20.flac to /content/sample_data/mp3folder_different/71-20.mp3
# Converted 114-14.flac to /content/sample_data/mp3folder_different/114-14.mp3
# Converted 87-15.flac to /content/sample_data/mp3folder_different/87-15.mp3
# Converted 133-18.flac to /content/sample_data/mp3folder_different/133-18.mp3
# Converted 33-15.flac to /content/sample_data/mp3folder_different/33-15.mp3
# Converted 69-11.flac to /content/sample_data/mp3folder_different/69-11.mp3
# Converted 69-19.flac to /content/sample_data/mp3folder_different/69-19.mp3
# Converted 127-15.flac to /content/sample_data/mp3folder_different/127-15.mp3
# Converted 109-19.flac to /content/sample_data/mp3folder_different/109-19.mp3
# Converted 93-19.flac to /content/sample_data/mp3folder_different/93-19.mp3
# Converted 140-16.flac to /content/sample_data/mp3folder_different/140-16.mp3
# Converted 76-19.flac to /content/sample_data/mp3folder_different/76-19.mp3
# Converted 115-18.flac to /content/sample_data/mp3folder_different/115-18.mp3
# Converted 143-17.flac to /content/sample_data/mp3folder_different/143-17.mp3
# Converted 40-11.flac to /content/sample_data/mp3folder_different/40-11.mp3
# Converted 74-20.flac to /content/sample_data/mp3folder_different/74-20.mp3
# Converted 65-11.flac to /content/sample_data/mp3folder_different/65-11.mp3
# Converted 86-13.flac to /content/sample_data/mp3folder_different/86-13.mp3
# Converted 10-17.flac to /content/sample_data/mp3folder_different/10-17.mp3
# Converted 22-20.flac to /content/sample_data/mp3folder_different/22-20.mp3
# Converted 14-11.flac to /content/sample_data/mp3folder_different/14-11.mp3
# Converted 52-19.flac to /content/sample_data/mp3folder_different/52-19.mp3
# Converted 106-16.flac to /content/sample_data/mp3folder_different/106-16.mp3
# Converted 7-12.flac to /content/sample_data/mp3folder_different/7-12.mp3
# Converted 51-13.flac to /content/sample_data/mp3folder_different/51-13.mp3
# Converted 136-17.flac to /content/sample_data/mp3folder_different/136-17.mp3
# Converted 105-20.flac to /content/sample_data/mp3folder_different/105-20.mp3
# Converted 69-18.flac to /content/sample_data/mp3folder_different/69-18.mp3
# Converted 135-13.flac to /content/sample_data/mp3folder_different/135-13.mp3
# Converted 37-20.flac to /content/sample_data/mp3folder_different/37-20.mp3
# Converted 78-13.flac to /content/sample_data/mp3folder_different/78-13.mp3
# Converted 66-13.flac to /content/sample_data/mp3folder_different/66-13.mp3
# Converted 64-13.flac to /content/sample_data/mp3folder_different/64-13.mp3
# Converted 19-14.flac to /content/sample_data/mp3folder_different/19-14.mp3
# Converted 45-17.flac to /content/sample_data/mp3folder_different/45-17.mp3
# Converted 29-11.flac to /content/sample_data/mp3folder_different/29-11.mp3
# Converted 16-19.flac to /content/sample_data/mp3folder_different/16-19.mp3
# Converted 8-11.flac to /content/sample_data/mp3folder_different/8-11.mp3
# Converted 39-16.flac to /content/sample_data/mp3folder_different/39-16.mp3
# Converted 132-18.flac to /content/sample_data/mp3folder_different/132-18.mp3
# Converted 105-12.flac to /content/sample_data/mp3folder_different/105-12.mp3
# Converted 10-20.flac to /content/sample_data/mp3folder_different/10-20.mp3
# Converted 99-20.flac to /content/sample_data/mp3folder_different/99-20.mp3
# Converted 87-20.flac to /content/sample_data/mp3folder_different/87-20.mp3
# Converted 66-15.flac to /content/sample_data/mp3folder_different/66-15.mp3
# Converted 61-19.flac to /content/sample_data/mp3folder_different/61-19.mp3
# Converted 84-15.flac to /content/sample_data/mp3folder_different/84-15.mp3
# Converted 19-15.flac to /content/sample_data/mp3folder_different/19-15.mp3
# Converted 96-14.flac to /content/sample_data/mp3folder_different/96-14.mp3
# Converted 114-19.flac to /content/sample_data/mp3folder_different/114-19.mp3
# Converted 38-20.flac to /content/sample_data/mp3folder_different/38-20.mp3
# Converted 96-20.flac to /content/sample_data/mp3folder_different/96-20.mp3
# Converted 147-14.flac to /content/sample_data/mp3folder_different/147-14.mp3
# Converted 112-14.flac to /content/sample_data/mp3folder_different/112-14.mp3
# Converted 121-15.flac to /content/sample_data/mp3folder_different/121-15.mp3
# Converted 43-18.flac to /content/sample_data/mp3folder_different/43-18.mp3
# Converted 10-16.flac to /content/sample_data/mp3folder_different/10-16.mp3
# Converted 73-20.flac to /content/sample_data/mp3folder_different/73-20.mp3
# Converted 139-16.flac to /content/sample_data/mp3folder_different/139-16.mp3
# Converted 82-17.flac to /content/sample_data/mp3folder_different/82-17.mp3
# Converted 69-15.flac to /content/sample_data/mp3folder_different/69-15.mp3
# Converted 105-13.flac to /content/sample_data/mp3folder_different/105-13.mp3
# Converted 30-16.flac to /content/sample_data/mp3folder_different/30-16.mp3
# Converted 128-11.flac to /content/sample_data/mp3folder_different/128-11.mp3
# Converted 121-16.flac to /content/sample_data/mp3folder_different/121-16.mp3
# Converted 31-17.flac to /content/sample_data/mp3folder_different/31-17.mp3
# Converted 146-15.flac to /content/sample_data/mp3folder_different/146-15.mp3
# Converted 82-13.flac to /content/sample_data/mp3folder_different/82-13.mp3
# Converted 131-19.flac to /content/sample_data/mp3folder_different/131-19.mp3
# Converted 87-12.flac to /content/sample_data/mp3folder_different/87-12.mp3
# Converted 146-13.flac to /content/sample_data/mp3folder_different/146-13.mp3
# Converted 18-12.flac to /content/sample_data/mp3folder_different/18-12.mp3
# Converted 108-20.flac to /content/sample_data/mp3folder_different/108-20.mp3
# Converted 69-16.flac to /content/sample_data/mp3folder_different/69-16.mp3
# Converted 105-15.flac to /content/sample_data/mp3folder_different/105-15.mp3
# Converted 92-14.flac to /content/sample_data/mp3folder_different/92-14.mp3
# Converted 66-16.flac to /content/sample_data/mp3folder_different/66-16.mp3
# Converted 14-15.flac to /content/sample_data/mp3folder_different/14-15.mp3
# Converted 59-18.flac to /content/sample_data/mp3folder_different/59-18.mp3
# Converted 58-14.flac to /content/sample_data/mp3folder_different/58-14.mp3
# Converted 18-14.flac to /content/sample_data/mp3folder_different/18-14.mp3
# Converted 26-13.flac to /content/sample_data/mp3folder_different/26-13.mp3
# Converted 98-15.flac to /content/sample_data/mp3folder_different/98-15.mp3
# Converted 15-14.flac to /content/sample_data/mp3folder_different/15-14.mp3
# Converted 89-16.flac to /content/sample_data/mp3folder_different/89-16.mp3
# Converted 109-12.flac to /content/sample_data/mp3folder_different/109-12.mp3
# Converted 88-18.flac to /content/sample_data/mp3folder_different/88-18.mp3
# Converted 104-17.flac to /content/sample_data/mp3folder_different/104-17.mp3
# Converted 21-20.flac to /content/sample_data/mp3folder_different/21-20.mp3
# Converted 146-11.flac to /content/sample_data/mp3folder_different/146-11.mp3
# Converted 38-15.flac to /content/sample_data/mp3folder_different/38-15.mp3
# Converted 73-12.flac to /content/sample_data/mp3folder_different/73-12.mp3
# Converted 80-14.flac to /content/sample_data/mp3folder_different/80-14.mp3
# Converted 90-11.flac to /content/sample_data/mp3folder_different/90-11.mp3
# Converted 58-18.flac to /content/sample_data/mp3folder_different/58-18.mp3
# Converted 6-19.flac to /content/sample_data/mp3folder_different/6-19.mp3
# Converted 27-14.flac to /content/sample_data/mp3folder_different/27-14.mp3
# Converted 107-14.flac to /content/sample_data/mp3folder_different/107-14.mp3
# Converted 90-14.flac to /content/sample_data/mp3folder_different/90-14.mp3
# Converted 144-12.flac to /content/sample_data/mp3folder_different/144-12.mp3
# Converted 62-17.flac to /content/sample_data/mp3folder_different/62-17.mp3
# Converted 82-15.flac to /content/sample_data/mp3folder_different/82-15.mp3
# Converted 117-15.flac to /content/sample_data/mp3folder_different/117-15.mp3
# Converted 78-19.flac to /content/sample_data/mp3folder_different/78-19.mp3
# Converted 123-18.flac to /content/sample_data/mp3folder_different/123-18.mp3
# Converted 35-14.flac to /content/sample_data/mp3folder_different/35-14.mp3
# Converted 42-18.flac to /content/sample_data/mp3folder_different/42-18.mp3
# Converted 12-20.flac to /content/sample_data/mp3folder_different/12-20.mp3
# Converted 63-13.flac to /content/sample_data/mp3folder_different/63-13.mp3
# Converted 38-18.flac to /content/sample_data/mp3folder_different/38-18.mp3
# Converted 67-17.flac to /content/sample_data/mp3folder_different/67-17.mp3
# Converted 130-18.flac to /content/sample_data/mp3folder_different/130-18.mp3
# Converted 36-11.flac to /content/sample_data/mp3folder_different/36-11.mp3
# Converted 64-12.flac to /content/sample_data/mp3folder_different/64-12.mp3
# Converted 63-14.flac to /content/sample_data/mp3folder_different/63-14.mp3
# Converted 104-16.flac to /content/sample_data/mp3folder_different/104-16.mp3
# Converted 122-12.flac to /content/sample_data/mp3folder_different/122-12.mp3
# Converted 77-14.flac to /content/sample_data/mp3folder_different/77-14.mp3
# Converted 139-11.flac to /content/sample_data/mp3folder_different/139-11.mp3
# Converted 126-11.flac to /content/sample_data/mp3folder_different/126-11.mp3
# Converted 148-15.flac to /content/sample_data/mp3folder_different/148-15.mp3
# Converted 2-11.flac to /content/sample_data/mp3folder_different/2-11.mp3
# Converted 85-19.flac to /content/sample_data/mp3folder_different/85-19.mp3
# Converted 47-12.flac to /content/sample_data/mp3folder_different/47-12.mp3
# Converted 119-14.flac to /content/sample_data/mp3folder_different/119-14.mp3
# Converted 125-11.flac to /content/sample_data/mp3folder_different/125-11.mp3
# Converted 41-12.flac to /content/sample_data/mp3folder_different/41-12.mp3
# Converted 115-20.flac to /content/sample_data/mp3folder_different/115-20.mp3
# Converted 11-18.flac to /content/sample_data/mp3folder_different/11-18.mp3
# Converted 3-13.flac to /content/sample_data/mp3folder_different/3-13.mp3
# Converted 144-18.flac to /content/sample_data/mp3folder_different/144-18.mp3
# Converted 24-11.flac to /content/sample_data/mp3folder_different/24-11.mp3
# Converted 101-15.flac to /content/sample_data/mp3folder_different/101-15.mp3
# Converted 40-15.flac to /content/sample_data/mp3folder_different/40-15.mp3
# Converted 45-15.flac to /content/sample_data/mp3folder_different/45-15.mp3
# Converted 24-12.flac to /content/sample_data/mp3folder_different/24-12.mp3
# Converted 92-11.flac to /content/sample_data/mp3folder_different/92-11.mp3
# Converted 99-14.flac to /content/sample_data/mp3folder_different/99-14.mp3
# Converted 14-18.flac to /content/sample_data/mp3folder_different/14-18.mp3
# Converted 17-20.flac to /content/sample_data/mp3folder_different/17-20.mp3
# Converted 150-19.flac to /content/sample_data/mp3folder_different/150-19.mp3
# Converted 95-14.flac to /content/sample_data/mp3folder_different/95-14.mp3
# Converted 30-19.flac to /content/sample_data/mp3folder_different/30-19.mp3
# Converted 88-13.flac to /content/sample_data/mp3folder_different/88-13.mp3
# Converted 20-18.flac to /content/sample_data/mp3folder_different/20-18.mp3
# Converted 9-11.flac to /content/sample_data/mp3folder_different/9-11.mp3
# Converted 136-20.flac to /content/sample_data/mp3folder_different/136-20.mp3
# Converted 88-12.flac to /content/sample_data/mp3folder_different/88-12.mp3
# Converted 4-19.flac to /content/sample_data/mp3folder_different/4-19.mp3
# Converted 60-16.flac to /content/sample_data/mp3folder_different/60-16.mp3
# Converted 123-11.flac to /content/sample_data/mp3folder_different/123-11.mp3
# Converted 98-18.flac to /content/sample_data/mp3folder_different/98-18.mp3
# Converted 65-16.flac to /content/sample_data/mp3folder_different/65-16.mp3
# Converted 51-12.flac to /content/sample_data/mp3folder_different/51-12.mp3
# Converted 111-12.flac to /content/sample_data/mp3folder_different/111-12.mp3
# Converted 113-19.flac to /content/sample_data/mp3folder_different/113-19.mp3
# Converted 63-20.flac to /content/sample_data/mp3folder_different/63-20.mp3
# Converted 22-15.flac to /content/sample_data/mp3folder_different/22-15.mp3
# Converted 63-12.flac to /content/sample_data/mp3folder_different/63-12.mp3
# Converted 13-14.flac to /content/sample_data/mp3folder_different/13-14.mp3
# Converted 62-14.flac to /content/sample_data/mp3folder_different/62-14.mp3
# Converted 110-16.flac to /content/sample_data/mp3folder_different/110-16.mp3
# Converted 26-17.flac to /content/sample_data/mp3folder_different/26-17.mp3
# Converted 27-11.flac to /content/sample_data/mp3folder_different/27-11.mp3
# Converted 76-18.flac to /content/sample_data/mp3folder_different/76-18.mp3
# Converted 104-20.flac to /content/sample_data/mp3folder_different/104-20.mp3
# Converted 56-12.flac to /content/sample_data/mp3folder_different/56-12.mp3
# Converted 103-14.flac to /content/sample_data/mp3folder_different/103-14.mp3
# Converted 104-15.flac to /content/sample_data/mp3folder_different/104-15.mp3
# Converted 119-18.flac to /content/sample_data/mp3folder_different/119-18.mp3
# Converted 126-13.flac to /content/sample_data/mp3folder_different/126-13.mp3
# Converted 53-18.flac to /content/sample_data/mp3folder_different/53-18.mp3
# Converted 52-16.flac to /content/sample_data/mp3folder_different/52-16.mp3
# Converted 105-17.flac to /content/sample_data/mp3folder_different/105-17.mp3
# Converted 94-16.flac to /content/sample_data/mp3folder_different/94-16.mp3
# Converted 113-15.flac to /content/sample_data/mp3folder_different/113-15.mp3
# Converted 99-17.flac to /content/sample_data/mp3folder_different/99-17.mp3
# Converted 77-18.flac to /content/sample_data/mp3folder_different/77-18.mp3
# Converted 150-12.flac to /content/sample_data/mp3folder_different/150-12.mp3
# Converted 120-14.flac to /content/sample_data/mp3folder_different/120-14.mp3
# Converted 43-13.flac to /content/sample_data/mp3folder_different/43-13.mp3
# Converted 120-18.flac to /content/sample_data/mp3folder_different/120-18.mp3
# Converted 7-16.flac to /content/sample_data/mp3folder_different/7-16.mp3
# Converted 79-16.flac to /content/sample_data/mp3folder_different/79-16.mp3
# Converted 39-15.flac to /content/sample_data/mp3folder_different/39-15.mp3
# Converted 110-11.flac to /content/sample_data/mp3folder_different/110-11.mp3
# Converted 32-19.flac to /content/sample_data/mp3folder_different/32-19.mp3
# Converted 42-14.flac to /content/sample_data/mp3folder_different/42-14.mp3
# Converted 13-17.flac to /content/sample_data/mp3folder_different/13-17.mp3
# Converted 64-15.flac to /content/sample_data/mp3folder_different/64-15.mp3
# Converted 3-14.flac to /content/sample_data/mp3folder_different/3-14.mp3
# Converted 103-16.flac to /content/sample_data/mp3folder_different/103-16.mp3
# Converted 22-16.flac to /content/sample_data/mp3folder_different/22-16.mp3
# Converted 150-15.flac to /content/sample_data/mp3folder_different/150-15.mp3
# Converted 37-15.flac to /content/sample_data/mp3folder_different/37-15.mp3
# Converted 102-13.flac to /content/sample_data/mp3folder_different/102-13.mp3
# Converted 54-18.flac to /content/sample_data/mp3folder_different/54-18.mp3
# Converted 32-12.flac to /content/sample_data/mp3folder_different/32-12.mp3
# Converted 136-18.flac to /content/sample_data/mp3folder_different/136-18.mp3
# Converted 84-18.flac to /content/sample_data/mp3folder_different/84-18.mp3
# Converted 71-18.flac to /content/sample_data/mp3folder_different/71-18.mp3
# Converted 49-12.flac to /content/sample_data/mp3folder_different/49-12.mp3
# Converted 42-16.flac to /content/sample_data/mp3folder_different/42-16.mp3
# Converted 142-14.flac to /content/sample_data/mp3folder_different/142-14.mp3
# Converted 80-11.flac to /content/sample_data/mp3folder_different/80-11.mp3
# Converted 133-19.flac to /content/sample_data/mp3folder_different/133-19.mp3
# Converted 145-19.flac to /content/sample_data/mp3folder_different/145-19.mp3
# Converted 139-15.flac to /content/sample_data/mp3folder_different/139-15.mp3
# Converted 64-17.flac to /content/sample_data/mp3folder_different/64-17.mp3
# Converted 21-11.flac to /content/sample_data/mp3folder_different/21-11.mp3
# Converted 53-11.flac to /content/sample_data/mp3folder_different/53-11.mp3
# Converted 4-11.flac to /content/sample_data/mp3folder_different/4-11.mp3
# Converted 131-15.flac to /content/sample_data/mp3folder_different/131-15.mp3
# Converted 59-13.flac to /content/sample_data/mp3folder_different/59-13.mp3
# Converted 105-16.flac to /content/sample_data/mp3folder_different/105-16.mp3
# Converted 54-15.flac to /content/sample_data/mp3folder_different/54-15.mp3
# Converted 55-11.flac to /content/sample_data/mp3folder_different/55-11.mp3
# Converted 15-20.flac to /content/sample_data/mp3folder_different/15-20.mp3
# Converted 99-16.flac to /content/sample_data/mp3folder_different/99-16.mp3
# Converted 34-20.flac to /content/sample_data/mp3folder_different/34-20.mp3
# Converted 132-16.flac to /content/sample_data/mp3folder_different/132-16.mp3
# Converted 143-16.flac to /content/sample_data/mp3folder_different/143-16.mp3
# Converted 67-19.flac to /content/sample_data/mp3folder_different/67-19.mp3
# Converted 101-19.flac to /content/sample_data/mp3folder_different/101-19.mp3
# Converted 118-13.flac to /content/sample_data/mp3folder_different/118-13.mp3
# Converted 91-18.flac to /content/sample_data/mp3folder_different/91-18.mp3
# Converted 38-12.flac to /content/sample_data/mp3folder_different/38-12.mp3
# Converted 104-19.flac to /content/sample_data/mp3folder_different/104-19.mp3
# Converted 14-19.flac to /content/sample_data/mp3folder_different/14-19.mp3
# Converted 28-14.flac to /content/sample_data/mp3folder_different/28-14.mp3
# Converted 30-11.flac to /content/sample_data/mp3folder_different/30-11.mp3
# Converted 98-14.flac to /content/sample_data/mp3folder_different/98-14.mp3
# Converted 136-15.flac to /content/sample_data/mp3folder_different/136-15.mp3
# Converted 127-12.flac to /content/sample_data/mp3folder_different/127-12.mp3
# Converted 119-12.flac to /content/sample_data/mp3folder_different/119-12.mp3
# Converted 102-19.flac to /content/sample_data/mp3folder_different/102-19.mp3
# Converted 97-12.flac to /content/sample_data/mp3folder_different/97-12.mp3
# Converted 116-14.flac to /content/sample_data/mp3folder_different/116-14.mp3
# Converted 12-12.flac to /content/sample_data/mp3folder_different/12-12.mp3
# Converted 53-13.flac to /content/sample_data/mp3folder_different/53-13.mp3
# Converted 93-14.flac to /content/sample_data/mp3folder_different/93-14.mp3
# Converted 44-16.flac to /content/sample_data/mp3folder_different/44-16.mp3
# Converted 3-19.flac to /content/sample_data/mp3folder_different/3-19.mp3
# Converted 13-13.flac to /content/sample_data/mp3folder_different/13-13.mp3
# Converted 36-13.flac to /content/sample_data/mp3folder_different/36-13.mp3
# Converted 62-19.flac to /content/sample_data/mp3folder_different/62-19.mp3
# Converted 41-15.flac to /content/sample_data/mp3folder_different/41-15.mp3
# Converted 102-16.flac to /content/sample_data/mp3folder_different/102-16.mp3
# Converted 132-13.flac to /content/sample_data/mp3folder_different/132-13.mp3
# Converted 142-17.flac to /content/sample_data/mp3folder_different/142-17.mp3
# Converted 34-18.flac to /content/sample_data/mp3folder_different/34-18.mp3
# Converted 117-17.flac to /content/sample_data/mp3folder_different/117-17.mp3
# Converted 70-18.flac to /content/sample_data/mp3folder_different/70-18.mp3
# Converted 39-19.flac to /content/sample_data/mp3folder_different/39-19.mp3
# Converted 1-16.flac to /content/sample_data/mp3folder_different/1-16.mp3
# Converted 8-14.flac to /content/sample_data/mp3folder_different/8-14.mp3
# Converted 27-19.flac to /content/sample_data/mp3folder_different/27-19.mp3
# Converted 120-12.flac to /content/sample_data/mp3folder_different/120-12.mp3
# Converted 64-14.flac to /content/sample_data/mp3folder_different/64-14.mp3
# Converted 36-15.flac to /content/sample_data/mp3folder_different/36-15.mp3
# Converted 8-12.flac to /content/sample_data/mp3folder_different/8-12.mp3
# Converted 116-19.flac to /content/sample_data/mp3folder_different/116-19.mp3
# Converted 26-14.flac to /content/sample_data/mp3folder_different/26-14.mp3
# Converted 11-14.flac to /content/sample_data/mp3folder_different/11-14.mp3
# Converted 107-12.flac to /content/sample_data/mp3folder_different/107-12.mp3
# Converted 9-20.flac to /content/sample_data/mp3folder_different/9-20.mp3
# Converted 11-13.flac to /content/sample_data/mp3folder_different/11-13.mp3
# Converted 66-17.flac to /content/sample_data/mp3folder_different/66-17.mp3
# Converted 143-12.flac to /content/sample_data/mp3folder_different/143-12.mp3
# Converted 19-17.flac to /content/sample_data/mp3folder_different/19-17.mp3
# Converted 27-17.flac to /content/sample_data/mp3folder_different/27-17.mp3
# Converted 133-13.flac to /content/sample_data/mp3folder_different/133-13.mp3
# Converted 23-17.flac to /content/sample_data/mp3folder_different/23-17.mp3
# Converted 15-11.flac to /content/sample_data/mp3folder_different/15-11.mp3
# Converted 31-11.flac to /content/sample_data/mp3folder_different/31-11.mp3
# Converted 126-19.flac to /content/sample_data/mp3folder_different/126-19.mp3
# Converted 127-19.flac to /content/sample_data/mp3folder_different/127-19.mp3
# Converted 73-16.flac to /content/sample_data/mp3folder_different/73-16.mp3
# Converted 23-12.flac to /content/sample_data/mp3folder_different/23-12.mp3
# Converted 7-18.flac to /content/sample_data/mp3folder_different/7-18.mp3
# Converted 94-18.flac to /content/sample_data/mp3folder_different/94-18.mp3
# Converted 58-11.flac to /content/sample_data/mp3folder_different/58-11.mp3
# Converted 120-17.flac to /content/sample_data/mp3folder_different/120-17.mp3
# Converted 106-20.flac to /content/sample_data/mp3folder_different/106-20.mp3
# Converted 70-11.flac to /content/sample_data/mp3folder_different/70-11.mp3
# Converted 86-17.flac to /content/sample_data/mp3folder_different/86-17.mp3
# Converted 83-20.flac to /content/sample_data/mp3folder_different/83-20.mp3
# Converted 41-13.flac to /content/sample_data/mp3folder_different/41-13.mp3
# Converted 48-12.flac to /content/sample_data/mp3folder_different/48-12.mp3
# Converted 49-11.flac to /content/sample_data/mp3folder_different/49-11.mp3
# Converted 106-11.flac to /content/sample_data/mp3folder_different/106-11.mp3
# Converted 38-17.flac to /content/sample_data/mp3folder_different/38-17.mp3
# Converted 125-19.flac to /content/sample_data/mp3folder_different/125-19.mp3
# Converted 20-15.flac to /content/sample_data/mp3folder_different/20-15.mp3
# Converted 103-13.flac to /content/sample_data/mp3folder_different/103-13.mp3
# Converted 18-20.flac to /content/sample_data/mp3folder_different/18-20.mp3
# Converted 40-12.flac to /content/sample_data/mp3folder_different/40-12.mp3
# Converted 122-15.flac to /content/sample_data/mp3folder_different/122-15.mp3
# Converted 108-17.flac to /content/sample_data/mp3folder_different/108-17.mp3
# Converted 35-19.flac to /content/sample_data/mp3folder_different/35-19.mp3
# Converted 10-11.flac to /content/sample_data/mp3folder_different/10-11.mp3
# Converted 70-17.flac to /content/sample_data/mp3folder_different/70-17.mp3
# Converted 148-20.flac to /content/sample_data/mp3folder_different/148-20.mp3
# Converted 65-17.flac to /content/sample_data/mp3folder_different/65-17.mp3
# Converted 140-17.flac to /content/sample_data/mp3folder_different/140-17.mp3
# Converted 113-13.flac to /content/sample_data/mp3folder_different/113-13.mp3
# Converted 148-11.flac to /content/sample_data/mp3folder_different/148-11.mp3
# Converted 39-13.flac to /content/sample_data/mp3folder_different/39-13.mp3
# Converted 120-13.flac to /content/sample_data/mp3folder_different/120-13.mp3
# Converted 97-17.flac to /content/sample_data/mp3folder_different/97-17.mp3
# Converted 50-11.flac to /content/sample_data/mp3folder_different/50-11.mp3
# Converted 90-15.flac to /content/sample_data/mp3folder_different/90-15.mp3
# Converted 62-18.flac to /content/sample_data/mp3folder_different/62-18.mp3
# Converted 146-19.flac to /content/sample_data/mp3folder_different/146-19.mp3
# Converted 33-12.flac to /content/sample_data/mp3folder_different/33-12.mp3
# Converted 93-20.flac to /content/sample_data/mp3folder_different/93-20.mp3
# Converted 121-13.flac to /content/sample_data/mp3folder_different/121-13.mp3
# Converted 138-11.flac to /content/sample_data/mp3folder_different/138-11.mp3
# Converted 122-20.flac to /content/sample_data/mp3folder_different/122-20.mp3
# Converted 20-20.flac to /content/sample_data/mp3folder_different/20-20.mp3
# Converted 123-16.flac to /content/sample_data/mp3folder_different/123-16.mp3
# Converted 6-13.flac to /content/sample_data/mp3folder_different/6-13.mp3
# Converted 23-11.flac to /content/sample_data/mp3folder_different/23-11.mp3
# Converted 57-17.flac to /content/sample_data/mp3folder_different/57-17.mp3
# Converted 79-13.flac to /content/sample_data/mp3folder_different/79-13.mp3
# Converted 75-18.flac to /content/sample_data/mp3folder_different/75-18.mp3
# Converted 69-14.flac to /content/sample_data/mp3folder_different/69-14.mp3
# Converted 149-17.flac to /content/sample_data/mp3folder_different/149-17.mp3
# Converted 46-16.flac to /content/sample_data/mp3folder_different/46-16.mp3
# Converted 135-11.flac to /content/sample_data/mp3folder_different/135-11.mp3
# Converted 122-14.flac to /content/sample_data/mp3folder_different/122-14.mp3
# Converted 130-17.flac to /content/sample_data/mp3folder_different/130-17.mp3
# Converted 123-12.flac to /content/sample_data/mp3folder_different/123-12.mp3
# Converted 120-16.flac to /content/sample_data/mp3folder_different/120-16.mp3
# Converted 75-16.flac to /content/sample_data/mp3folder_different/75-16.mp3
# Converted 20-12.flac to /content/sample_data/mp3folder_different/20-12.mp3
# Converted 99-11.flac to /content/sample_data/mp3folder_different/99-11.mp3
# Converted 135-14.flac to /content/sample_data/mp3folder_different/135-14.mp3
# Converted 64-18.flac to /content/sample_data/mp3folder_different/64-18.mp3
# Converted 96-19.flac to /content/sample_data/mp3folder_different/96-19.mp3
# Converted 63-11.flac to /content/sample_data/mp3folder_different/63-11.mp3
# Converted 133-15.flac to /content/sample_data/mp3folder_different/133-15.mp3
# Converted 149-13.flac to /content/sample_data/mp3folder_different/149-13.mp3
# Converted 59-14.flac to /content/sample_data/mp3folder_different/59-14.mp3
# Converted 75-20.flac to /content/sample_data/mp3folder_different/75-20.mp3
# Converted 128-15.flac to /content/sample_data/mp3folder_different/128-15.mp3
# Converted 74-15.flac to /content/sample_data/mp3folder_different/74-15.mp3
# Converted 55-20.flac to /content/sample_data/mp3folder_different/55-20.mp3
# Converted 100-14.flac to /content/sample_data/mp3folder_different/100-14.mp3
# Converted 133-11.flac to /content/sample_data/mp3folder_different/133-11.mp3
# Converted 91-14.flac to /content/sample_data/mp3folder_different/91-14.mp3
# Converted 112-16.flac to /content/sample_data/mp3folder_different/112-16.mp3
# Converted 45-12.flac to /content/sample_data/mp3folder_different/45-12.mp3
# Converted 141-19.flac to /content/sample_data/mp3folder_different/141-19.mp3
# Converted 19-13.flac to /content/sample_data/mp3folder_different/19-13.mp3
# Converted 95-17.flac to /content/sample_data/mp3folder_different/95-17.mp3
# Converted 147-13.flac to /content/sample_data/mp3folder_different/147-13.mp3
# Converted 80-15.flac to /content/sample_data/mp3folder_different/80-15.mp3
# Converted 82-16.flac to /content/sample_data/mp3folder_different/82-16.mp3
# Converted 4-20.flac to /content/sample_data/mp3folder_different/4-20.mp3
# Converted 143-11.flac to /content/sample_data/mp3folder_different/143-11.mp3
# Converted 60-15.flac to /content/sample_data/mp3folder_different/60-15.mp3
# Converted 67-20.flac to /content/sample_data/mp3folder_different/67-20.mp3
# Converted 50-18.flac to /content/sample_data/mp3folder_different/50-18.mp3
# Converted 106-12.flac to /content/sample_data/mp3folder_different/106-12.mp3
# Converted 25-18.flac to /content/sample_data/mp3folder_different/25-18.mp3
# Converted 47-17.flac to /content/sample_data/mp3folder_different/47-17.mp3
# Converted 9-18.flac to /content/sample_data/mp3folder_different/9-18.mp3
# Converted 15-12.flac to /content/sample_data/mp3folder_different/15-12.mp3
# Converted 57-12.flac to /content/sample_data/mp3folder_different/57-12.mp3
# Converted 10-13.flac to /content/sample_data/mp3folder_different/10-13.mp3
# Converted 85-18.flac to /content/sample_data/mp3folder_different/85-18.mp3
# Converted 94-17.flac to /content/sample_data/mp3folder_different/94-17.mp3
# Converted 1-15.flac to /content/sample_data/mp3folder_different/1-15.mp3
# Converted 51-15.flac to /content/sample_data/mp3folder_different/51-15.mp3
# Converted 134-15.flac to /content/sample_data/mp3folder_different/134-15.mp3
# Converted 66-19.flac to /content/sample_data/mp3folder_different/66-19.mp3
# Converted 150-11.flac to /content/sample_data/mp3folder_different/150-11.mp3
# Converted 13-11.flac to /content/sample_data/mp3folder_different/13-11.mp3
# Converted 60-11.flac to /content/sample_data/mp3folder_different/60-11.mp3
# Converted 49-13.flac to /content/sample_data/mp3folder_different/49-13.mp3
# Converted 16-15.flac to /content/sample_data/mp3folder_different/16-15.mp3
# Converted 61-17.flac to /content/sample_data/mp3folder_different/61-17.mp3
# Converted 24-18.flac to /content/sample_data/mp3folder_different/24-18.mp3
# Converted 22-14.flac to /content/sample_data/mp3folder_different/22-14.mp3
# Converted 44-15.flac to /content/sample_data/mp3folder_different/44-15.mp3
# Converted 86-15.flac to /content/sample_data/mp3folder_different/86-15.mp3
# Converted 146-16.flac to /content/sample_data/mp3folder_different/146-16.mp3
# Converted 37-16.flac to /content/sample_data/mp3folder_different/37-16.mp3
# Converted 70-20.flac to /content/sample_data/mp3folder_different/70-20.mp3
# Converted 122-13.flac to /content/sample_data/mp3folder_different/122-13.mp3
# Converted 150-20.flac to /content/sample_data/mp3folder_different/150-20.mp3
# Converted 95-15.flac to /content/sample_data/mp3folder_different/95-15.mp3
# Converted 86-20.flac to /content/sample_data/mp3folder_different/86-20.mp3
# Converted 51-16.flac to /content/sample_data/mp3folder_different/51-16.mp3
# Converted 67-12.flac to /content/sample_data/mp3folder_different/67-12.mp3
# Converted 95-13.flac to /content/sample_data/mp3folder_different/95-13.mp3
# Converted 75-19.flac to /content/sample_data/mp3folder_different/75-19.mp3
# Converted 147-11.flac to /content/sample_data/mp3folder_different/147-11.mp3
# Converted 12-15.flac to /content/sample_data/mp3folder_different/12-15.mp3
# Converted 136-11.flac to /content/sample_data/mp3folder_different/136-11.mp3
# Converted 85-11.flac to /content/sample_data/mp3folder_different/85-11.mp3
# Converted 24-13.flac to /content/sample_data/mp3folder_different/24-13.mp3
# Converted 136-13.flac to /content/sample_data/mp3folder_different/136-13.mp3
# Converted 73-17.flac to /content/sample_data/mp3folder_different/73-17.mp3
# Converted 141-18.flac to /content/sample_data/mp3folder_different/141-18.mp3
# Converted 73-13.flac to /content/sample_data/mp3folder_different/73-13.mp3
# Converted 5-11.flac to /content/sample_data/mp3folder_different/5-11.mp3
# Converted 145-17.flac to /content/sample_data/mp3folder_different/145-17.mp3
# Converted 44-11.flac to /content/sample_data/mp3folder_different/44-11.mp3
# Converted 144-14.flac to /content/sample_data/mp3folder_different/144-14.mp3
# Converted 104-11.flac to /content/sample_data/mp3folder_different/104-11.mp3
# Converted 49-16.flac to /content/sample_data/mp3folder_different/49-16.mp3
# Converted 19-20.flac to /content/sample_data/mp3folder_different/19-20.mp3
# Converted 49-15.flac to /content/sample_data/mp3folder_different/49-15.mp3
# Converted 102-12.flac to /content/sample_data/mp3folder_different/102-12.mp3
# Converted 111-15.flac to /content/sample_data/mp3folder_different/111-15.mp3
# Converted 120-19.flac to /content/sample_data/mp3folder_different/120-19.mp3
# Converted 136-19.flac to /content/sample_data/mp3folder_different/136-19.mp3
# Converted 150-13.flac to /content/sample_data/mp3folder_different/150-13.mp3
# Converted 137-15.flac to /content/sample_data/mp3folder_different/137-15.mp3
# Converted 26-20.flac to /content/sample_data/mp3folder_different/26-20.mp3
# Converted 79-15.flac to /content/sample_data/mp3folder_different/79-15.mp3
# ...
# Converted 68-11.flac to /content/sample_data/mp3folder_different/68-11.mp3
# Converted 4-12.flac to /content/sample_data/mp3folder_different/4-12.mp3
# Converted 135-16.flac to /content/sample_data/mp3folder_different/135-16.mp3
# Converted 147-15.flac to /content/sample_data/mp3folder_different/147-15.mp3
# Converted 15-16.flac to /content/sample_data/mp3folder_different/15-16.mp3
# Converted 119-16.flac to /content/sample_data/mp3folder_different/119-16.mp3
# Converted 64-11.flac to /content/sample_data/mp3folder_different/64-11.mp3
# Converted 78-11.flac to /content/sample_data/mp3folder_different/78-11.mp3
# Converted 132-11.flac to /content/sample_data/mp3folder_different/132-11.mp3
# Converted 52-18.flac to /content/sample_data/mp3folder_different/52-18.mp3
# Converted 62-15.flac to /content/sample_data/mp3folder_different/62-15.mp3
# Converted 144-19.flac to /content/sample_data/mp3folder_different/144-19.mp3
# Converted 110-20.flac to /content/sample_data/mp3folder_different/110-20.mp3
# Converted 26-19.flac to /content/sample_data/mp3folder_different/26-19.mp3
# Converted 56-11.flac to /content/sample_data/mp3folder_different/56-11.mp3
# Converted 26-12.flac to /content/sample_data/mp3folder_different/26-12.mp3
# Converted 86-19.flac to /content/sample_data/mp3folder_different/86-19.mp3
# Converted 61-20.flac to /content/sample_data/mp3folder_different/61-20.mp3
# Converted 129-14.flac to /content/sample_data/mp3folder_different/129-14.mp3
# Converted 95-19.flac to /content/sample_data/mp3folder_different/95-19.mp3
# Converted 98-12.flac to /content/sample_data/mp3folder_different/98-12.mp3
# Converted 119-13.flac to /content/sample_data/mp3folder_different/119-13.mp3
# Converted 8-16.flac to /content/sample_data/mp3folder_different/8-16.mp3
# Converted 76-15.flac to /content/sample_data/mp3folder_different/76-15.mp3
# Converted 49-19.flac to /content/sample_data/mp3folder_different/49-19.mp3
# Converted 147-16.flac to /content/sample_data/mp3folder_different/147-16.mp3
# Converted 62-16.flac to /content/sample_data/mp3folder_different/62-16.mp3
# Converted 5-20.flac to /content/sample_data/mp3folder_different/5-20.mp3
# Converted 42-11.flac to /content/sample_data/mp3folder_different/42-11.mp3
# Converted 109-17.flac to /content/sample_data/mp3folder_different/109-17.mp3
# Converted 89-12.flac to /content/sample_data/mp3folder_different/89-12.mp3
# Converted 140-18.flac to /content/sample_data/mp3folder_different/140-18.mp3
# Converted 127-20.flac to /content/sample_data/mp3folder_different/127-20.mp3
# Converted 28-17.flac to /content/sample_data/mp3folder_different/28-17.mp3
# Converted 13-15.flac to /content/sample_data/mp3folder_different/13-15.mp3
# Converted 67-13.flac to /content/sample_data/mp3folder_different/67-13.mp3
# Converted 71-17.flac to /content/sample_data/mp3folder_different/71-17.mp3
# Converted 129-11.flac to /content/sample_data/mp3folder_different/129-11.mp3
# Converted 45-19.flac to /content/sample_data/mp3folder_different/45-19.mp3
# Converted 85-15.flac to /content/sample_data/mp3folder_different/85-15.mp3
# Converted 7-20.flac to /content/sample_data/mp3folder_different/7-20.mp3
# Converted 86-18.flac to /content/sample_data/mp3folder_different/86-18.mp3
# Converted 11-16.flac to /content/sample_data/mp3folder_different/11-16.mp3
# Converted 58-12.flac to /content/sample_data/mp3folder_different/58-12.mp3
# Converted 38-14.flac to /content/sample_data/mp3folder_different/38-14.mp3
# Converted 17-11.flac to /content/sample_data/mp3folder_different/17-11.mp3
# Converted 2-17.flac to /content/sample_data/mp3folder_different/2-17.mp3
# Converted 2-15.flac to /content/sample_data/mp3folder_different/2-15.mp3
# Converted 5-14.flac to /content/sample_data/mp3folder_different/5-14.mp3
# Converted 26-18.flac to /content/sample_data/mp3folder_different/26-18.mp3
# Converted 27-18.flac to /content/sample_data/mp3folder_different/27-18.mp3
# Converted 118-12.flac to /content/sample_data/mp3folder_different/118-12.mp3
# Converted 80-13.flac to /content/sample_data/mp3folder_different/80-13.mp3
# Converted 10-15.flac to /content/sample_data/mp3folder_different/10-15.mp3
# Converted 142-20.flac to /content/sample_data/mp3folder_different/142-20.mp3
# Converted 149-11.flac to /content/sample_data/mp3folder_different/149-11.mp3
# Converted 142-13.flac to /content/sample_data/mp3folder_different/142-13.mp3
# Converted 98-17.flac to /content/sample_data/mp3folder_different/98-17.mp3
# Converted 140-13.flac to /content/sample_data/mp3folder_different/140-13.mp3
# Converted 124-12.flac to /content/sample_data/mp3folder_different/124-12.mp3
# Converted 52-13.flac to /content/sample_data/mp3folder_different/52-13.mp3
# Converted 23-19.flac to /content/sample_data/mp3folder_different/23-19.mp3
# Converted 100-20.flac to /content/sample_data/mp3folder_different/100-20.mp3
# Converted 88-19.flac to /content/sample_data/mp3folder_different/88-19.mp3
# Converted 109-18.flac to /content/sample_data/mp3folder_different/109-18.mp3
# Converted 146-20.flac to /content/sample_data/mp3folder_different/146-20.mp3
# Converted 110-15.flac to /content/sample_data/mp3folder_different/110-15.mp3
# Converted 48-13.flac to /content/sample_data/mp3folder_different/48-13.mp3
# Converted 81-18.flac to /content/sample_data/mp3folder_different/81-18.mp3
# Converted 44-12.flac to /content/sample_data/mp3folder_different/44-12.mp3
# Converted 120-20.flac to /content/sample_data/mp3folder_different/120-20.mp3
# Converted 3-11.flac to /content/sample_data/mp3folder_different/3-11.mp3
# Converted 145-13.flac to /content/sample_data/mp3folder_different/145-13.mp3
# Converted 71-11.flac to /content/sample_data/mp3folder_different/71-11.mp3
# Converted 18-13.flac to /content/sample_data/mp3folder_different/18-13.mp3
# Converted 65-13.flac to /content/sample_data/mp3folder_different/65-13.mp3
# Converted 79-20.flac to /content/sample_data/mp3folder_different/79-20.mp3
# Converted 92-20.flac to /content/sample_data/mp3folder_different/92-20.mp3
# Converted 48-17.flac to /content/sample_data/mp3folder_different/48-17.mp3
# Converted 50-12.flac to /content/sample_data/mp3folder_different/50-12.mp3
# Converted 38-11.flac to /content/sample_data/mp3folder_different/38-11.mp3
# Converted 3-18.flac to /content/sample_data/mp3folder_different/3-18.mp3
# Converted 79-14.flac to /content/sample_data/mp3folder_different/79-14.mp3
# Converted 42-19.flac to /content/sample_data/mp3folder_different/42-19.mp3
# Converted 55-18.flac to /content/sample_data/mp3folder_different/55-18.mp3
# Converted 61-13.flac to /content/sample_data/mp3folder_different/61-13.mp3
# Converted 15-18.flac to /content/sample_data/mp3folder_different/15-18.mp3
# Converted 75-11.flac to /content/sample_data/mp3folder_different/75-11.mp3
# Converted 117-12.flac to /content/sample_data/mp3folder_different/117-12.mp3
# Converted 91-17.flac to /content/sample_data/mp3folder_different/91-17.mp3
# Converted 39-20.flac to /content/sample_data/mp3folder_different/39-20.mp3
# Converted 109-11.flac to /content/sample_data/mp3folder_different/109-11.mp3
# Converted 85-16.flac to /content/sample_data/mp3folder_different/85-16.mp3
# Converted 23-20.flac to /content/sample_data/mp3folder_different/23-20.mp3
# Converted 93-17.flac to /content/sample_data/mp3folder_different/93-17.mp3
# Converted 2-19.flac to /content/sample_data/mp3folder_different/2-19.mp3
# Converted 114-20.flac to /content/sample_data/mp3folder_different/114-20.mp3
# Converted 58-15.flac to /content/sample_data/mp3folder_different/58-15.mp3
# Converted 57-14.flac to /content/sample_data/mp3folder_different/57-14.mp3
# Converted 113-16.flac to /content/sample_data/mp3folder_different/113-16.mp3
# Converted 144-17.flac to /content/sample_data/mp3folder_different/144-17.mp3
# Converted 38-13.flac to /content/sample_data/mp3folder_different/38-13.mp3
# Converted 83-19.flac to /content/sample_data/mp3folder_different/83-19.mp3
# Converted 107-15.flac to /content/sample_data/mp3folder_different/107-15.mp3
# Converted 92-12.flac to /content/sample_data/mp3folder_different/92-12.mp3
# Converted 136-14.flac to /content/sample_data/mp3folder_different/136-14.mp3
# Converted 37-13.flac to /content/sample_data/mp3folder_different/37-13.mp3
# Converted 10-19.flac to /content/sample_data/mp3folder_different/10-19.mp3
# Converted 100-11.flac to /content/sample_data/mp3folder_different/100-11.mp3
# Converted 128-12.flac to /content/sample_data/mp3folder_different/128-12.mp3
# Converted 88-11.flac to /content/sample_data/mp3folder_different/88-11.mp3
# Converted 102-11.flac to /content/sample_data/mp3folder_different/102-11.mp3
# Converted 50-14.flac to /content/sample_data/mp3folder_different/50-14.mp3
# Converted 36-14.flac to /content/sample_data/mp3folder_different/36-14.mp3
# Converted 107-20.flac to /content/sample_data/mp3folder_different/107-20.mp3
# Converted 73-15.flac to /content/sample_data/mp3folder_different/73-15.mp3
# Converted 44-14.flac to /content/sample_data/mp3folder_different/44-14.mp3
# Converted 16-12.flac to /content/sample_data/mp3folder_different/16-12.mp3
# Converted 27-16.flac to /content/sample_data/mp3folder_different/27-16.mp3
# Converted 113-17.flac to /content/sample_data/mp3folder_different/113-17.mp3
# Converted 80-20.flac to /content/sample_data/mp3folder_different/80-20.mp3
# Converted 91-13.flac to /content/sample_data/mp3folder_different/91-13.mp3
# Converted 100-12.flac to /content/sample_data/mp3folder_different/100-12.mp3
# Converted 80-19.flac to /content/sample_data/mp3folder_different/80-19.mp3
# Converted 60-14.flac to /content/sample_data/mp3folder_different/60-14.mp3
# Converted 108-16.flac to /content/sample_data/mp3folder_different/108-16.mp3
# Converted 45-13.flac to /content/sample_data/mp3folder_different/45-13.mp3
# Converted 67-18.flac to /content/sample_data/mp3folder_different/67-18.mp3
# Converted 1-12.flac to /content/sample_data/mp3folder_different/1-12.mp3
# Converted 78-20.flac to /content/sample_data/mp3folder_different/78-20.mp3
# Converted 115-11.flac to /content/sample_data/mp3folder_different/115-11.mp3
# Converted 53-12.flac to /content/sample_data/mp3folder_different/53-12.mp3
# Converted 117-19.flac to /content/sample_data/mp3folder_different/117-19.mp3
# Converted 39-18.flac to /content/sample_data/mp3folder_different/39-18.mp3
# Converted 138-17.flac to /content/sample_data/mp3folder_different/138-17.mp3
# Converted 126-14.flac to /content/sample_data/mp3folder_different/126-14.mp3
# Converted 131-17.flac to /content/sample_data/mp3folder_different/131-17.mp3
# Converted 147-18.flac to /content/sample_data/mp3folder_different/147-18.mp3
# Converted 116-18.flac to /content/sample_data/mp3folder_different/116-18.mp3
# Converted 128-18.flac to /content/sample_data/mp3folder_different/128-18.mp3
# Converted 21-16.flac to /content/sample_data/mp3folder_different/21-16.mp3
# Converted 52-17.flac to /content/sample_data/mp3folder_different/52-17.mp3
# Converted 134-16.flac to /content/sample_data/mp3folder_different/134-16.mp3
# Converted 68-12.flac to /content/sample_data/mp3folder_different/68-12.mp3
# Converted 107-18.flac to /content/sample_data/mp3folder_different/107-18.mp3
# Converted 98-13.flac to /content/sample_data/mp3folder_different/98-13.mp3
# Converted 128-16.flac to /content/sample_data/mp3folder_different/128-16.mp3
# Converted 61-11.flac to /content/sample_data/mp3folder_different/61-11.mp3
# Converted 31-16.flac to /content/sample_data/mp3folder_different/31-16.mp3
# Converted 77-12.flac to /content/sample_data/mp3folder_different/77-12.mp3
# Converted 55-13.flac to /content/sample_data/mp3folder_different/55-13.mp3
# Converted 52-14.flac to /content/sample_data/mp3folder_different/52-14.mp3
# Converted 97-20.flac to /content/sample_data/mp3folder_different/97-20.mp3
# Converted 128-13.flac to /content/sample_data/mp3folder_different/128-13.mp3
# Converted 108-15.flac to /content/sample_data/mp3folder_different/108-15.mp3
# Converted 83-14.flac to /content/sample_data/mp3folder_different/83-14.mp3
# Converted 95-11.flac to /content/sample_data/mp3folder_different/95-11.mp3
# Converted 150-18.flac to /content/sample_data/mp3folder_different/150-18.mp3
# Converted 108-18.flac to /content/sample_data/mp3folder_different/108-18.mp3
# Converted 84-20.flac to /content/sample_data/mp3folder_different/84-20.mp3
# Converted 52-11.flac to /content/sample_data/mp3folder_different/52-11.mp3
# Converted 83-16.flac to /content/sample_data/mp3folder_different/83-16.mp3
# Converted 62-12.flac to /content/sample_data/mp3folder_different/62-12.mp3
# Converted 114-11.flac to /content/sample_data/mp3folder_different/114-11.mp3
# Converted 135-12.flac to /content/sample_data/mp3folder_different/135-12.mp3
# Converted 59-20.flac to /content/sample_data/mp3folder_different/59-20.mp3
# Converted 19-18.flac to /content/sample_data/mp3folder_different/19-18.mp3
# Converted 112-19.flac to /content/sample_data/mp3folder_different/112-19.mp3
# Converted 104-12.flac to /content/sample_data/mp3folder_different/104-12.mp3
# Converted 47-20.flac to /content/sample_data/mp3folder_different/47-20.mp3
# Converted 13-20.flac to /content/sample_data/mp3folder_different/13-20.mp3
# Converted 62-13.flac to /content/sample_data/mp3folder_different/62-13.mp3
# Converted 55-12.flac to /content/sample_data/mp3folder_different/55-12.mp3
# Converted 146-17.flac to /content/sample_data/mp3folder_different/146-17.mp3
# Converted 7-13.flac to /content/sample_data/mp3folder_different/7-13.mp3
# Converted 54-13.flac to /content/sample_data/mp3folder_different/54-13.mp3
# Converted 50-17.flac to /content/sample_data/mp3folder_different/50-17.mp3
# Converted 9-12.flac to /content/sample_data/mp3folder_different/9-12.mp3
# Converted 10-14.flac to /content/sample_data/mp3folder_different/10-14.mp3
# Converted 128-17.flac to /content/sample_data/mp3folder_different/128-17.mp3
# Converted 15-17.flac to /content/sample_data/mp3folder_different/15-17.mp3
# Converted 33-16.flac to /content/sample_data/mp3folder_different/33-16.mp3
# Converted 30-15.flac to /content/sample_data/mp3folder_different/30-15.mp3
# Converted 33-18.flac to /content/sample_data/mp3folder_different/33-18.mp3
# Converted 6-14.flac to /content/sample_data/mp3folder_different/6-14.mp3
# Converted 100-17.flac to /content/sample_data/mp3folder_different/100-17.mp3
# Converted 99-18.flac to /content/sample_data/mp3folder_different/99-18.mp3
# Converted 35-13.flac to /content/sample_data/mp3folder_different/35-13.mp3
# Converted 79-11.flac to /content/sample_data/mp3folder_different/79-11.mp3
# Converted 142-18.flac to /content/sample_data/mp3folder_different/142-18.mp3
# Converted 7-17.flac to /content/sample_data/mp3folder_different/7-17.mp3
# Converted 135-15.flac to /content/sample_data/mp3folder_different/135-15.mp3
# Converted 2-12.flac to /content/sample_data/mp3folder_different/2-12.mp3
# Converted 71-19.flac to /content/sample_data/mp3folder_different/71-19.mp3
# Converted 93-12.flac to /content/sample_data/mp3folder_different/93-12.mp3
# Converted 138-18.flac to /content/sample_data/mp3folder_different/138-18.mp3
# Converted 42-17.flac to /content/sample_data/mp3folder_different/42-17.mp3
# Converted 126-16.flac to /content/sample_data/mp3folder_different/126-16.mp3
# Converted 114-13.flac to /content/sample_data/mp3folder_different/114-13.mp3
# Converted 89-15.flac to /content/sample_data/mp3folder_different/89-15.mp3
# Converted 3-15.flac to /content/sample_data/mp3folder_different/3-15.mp3
# Converted 75-17.flac to /content/sample_data/mp3folder_different/75-17.mp3
# Converted 130-19.flac to /content/sample_data/mp3folder_different/130-19.mp3
# Converted 68-16.flac to /content/sample_data/mp3folder_different/68-16.mp3
# Converted 51-18.flac to /content/sample_data/mp3folder_different/51-18.mp3
# Converted 85-13.flac to /content/sample_data/mp3folder_different/85-13.mp3
# Converted 66-20.flac to /content/sample_data/mp3folder_different/66-20.mp3
# Converted 51-14.flac to /content/sample_data/mp3folder_different/51-14.mp3
# Converted 149-18.flac to /content/sample_data/mp3folder_different/149-18.mp3
# Converted 103-11.flac to /content/sample_data/mp3folder_different/103-11.mp3
# Extracting audio features from MP3 files...
# CSV file saved as different.csv
